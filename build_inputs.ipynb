# %%
import os

import sa_popgrid

# %%
root_dir = '/Users/d3y010/projects/population/walkthrough'

# directory of the unzipped data from Zenodo
data_dir = os.path.join(root_dir, 'zoraghein-oneill_population_gravity_inputs_outputs')

# directory that will hold the newly modified inputs.
output_dir = os.path.join(root_dir, 'updated_inputs_150km')

# list of years as 4-digit integers to process
target_year_list = [2000, 2010]

sa_popgrid.build_new_data(data_dir, output_dir, target_year_list)
# Out:
# Processing state:  oregon
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  pennsylvania
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  ohio
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  oklahoma
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  mississippi
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  montana
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  minnesota
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  missouri
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  nebraska
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  new_hampshire
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  north_carolina
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  north_dakota
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  kentucky
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  louisiana
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  indiana
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  kansas
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  maine
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  florida
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  michigan
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  georgia
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  massachusetts
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  district_of_columbia
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  maryland
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  delaware
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  idaho
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  illinois
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  iowa
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  alabama
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  arkansas
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  colorado
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  connecticut
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  arizona
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  california
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  west_virginia
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  wyoming
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  washington
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  wisconsin
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  south_dakota
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
# Running tests to validate population rasters...
# Processing year:  2010
# Preparing data...
# Building new population rasters...
# Running tests to validate population rasters...
# Copying additional unmodified files to the inputs directory...
# Removing the temporary directory and its contents...
# All tests passed.  Data created successfully.
#
# Processing state:  tennessee
# Processing year:  2000
# Preparing data...
# Building new coordinate and indicies files...
# Running tests to validate coordinate and indices files...
# Building new suitability mask raster...
# Running test to validate suitability mask raster...
# Building new population rasters...
